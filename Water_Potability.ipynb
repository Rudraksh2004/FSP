# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/water_potability.csv")
data
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# ...            ...             ...              ...        ...         ...
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [3276 rows x 10 columns]

# %%
x=data.iloc[:,0:-1].values
x
# Out:
# array([[           nan, 2.04890455e+02, 2.07913190e+04, ...,
#         1.03797831e+01, 8.69909705e+01, 2.96313538e+00],
#        [3.71608008e+00, 1.29422921e+02, 1.86300579e+04, ...,
#         1.51800131e+01, 5.63290763e+01, 4.50065627e+00],
#        [8.09912419e+00, 2.24236259e+02, 1.99095417e+04, ...,
#         1.68686369e+01, 6.64200925e+01, 3.05593375e+00],
#        ...,
#        [9.41951032e+00, 1.75762646e+02, 3.31555782e+04, ...,
#         1.10390697e+01, 6.98454003e+01, 3.29887550e+00],
#        [5.12676292e+00, 2.30603758e+02, 1.19838694e+04, ...,
#         1.11689462e+01, 7.74882131e+01, 4.70865847e+00],
#        [7.87467136e+00, 1.95102299e+02, 1.74041771e+04, ...,
#         1.61403676e+01, 7.86984463e+01, 2.30914906e+00]])

# %%
from sklearn.preprocessing import LabelEncoder
en=LabelEncoder()
x[:,0]=en.fit_transform(x[:,0])
x
# Out:
# array([[2.78500000e+03, 2.04890455e+02, 2.07913190e+04, ...,
#         1.03797831e+01, 8.69909705e+01, 2.96313538e+00],
#        [4.90000000e+01, 1.29422921e+02, 1.86300579e+04, ...,
#         1.51800131e+01, 5.63290763e+01, 4.50065627e+00],
#        [2.10700000e+03, 2.24236259e+02, 1.99095417e+04, ...,
#         1.68686369e+01, 6.64200925e+01, 3.05593375e+00],
#        ...,
#        [2.58100000e+03, 1.75762646e+02, 3.31555782e+04, ...,
#         1.10390697e+01, 6.98454003e+01, 3.29887550e+00],
#        [2.83000000e+02, 2.30603758e+02, 1.19838694e+04, ...,
#         1.11689462e+01, 7.74882131e+01, 4.70865847e+00],
#        [1.96900000e+03, 1.95102299e+02, 1.74041771e+04, ...,
#         1.61403676e+01, 7.86984463e+01, 2.30914906e+00]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.32672130e+00,  2.59194711e-01, -1.39470871e-01, ...,
#         -1.18065057e+00,  1.27344509e+00, -1.28629758e+00],
#        [-1.73851085e+00, -2.03641367e+00, -3.85986650e-01, ...,
#          2.70597240e-01, -6.22493246e-01,  6.84217891e-01],
#        [ 5.67135265e-01,  8.47664833e-01, -2.40047337e-01, ...,
#          7.81116857e-01,  1.47161514e-03, -1.16736546e+00],
#        ...,
#        [ 1.09817329e+00, -6.26829230e-01,  1.27080989e+00, ...,
#         -9.81329234e-01,  2.13271066e-01, -8.56006782e-01],
#        [-1.47635284e+00,  1.04135450e+00, -1.14405809e+00, ...,
#         -9.42063817e-01,  6.85854453e-01,  9.50797383e-01],
#        [ 4.12529257e-01, -3.85462310e-02, -5.25811937e-01, ...,
#          5.60940070e-01,  7.60687650e-01, -2.12445866e+00]])

# %%
y=data.iloc[:,4].values
y
# Out:
# array([368.51644135,          nan,          nan, ...,          nan,
#                 nan,          nan])

# %%
from keras.models import Sequential
from keras.layers import Dense
model=Sequential()
model.add(Dense(units=64,activation="relu",input_dim=9))
model.add(Dense(units=32,activation="relu"))
model.add(Dense(units=16,activation="relu"))
model.add(Dense(units=1,activation="linear"))
model.compile(optimizer="adam",loss="mean_squared_error")
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                │ (None, 64)             │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,265 (12.75 KB)
#  Trainable params: 3,265 (12.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from sklearn.model_selection import train_test_split
y = data.iloc[:, -1]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
model.fit(x_train,y_train,epochs=100,batch_size=10,validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: nan - val_loss: nan
# Epoch 2/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 3/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 4/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 5/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 6/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 7/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 8/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 9/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: nan - val_loss: nan
# Epoch 10/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: nan - val_loss: nan
# Epoch 11/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: nan - val_loss: nan
# Epoch 12/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: nan - val_loss: nan
# Epoch 13/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 14/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: nan - val_loss: nan
# Epoch 15/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 16/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 17/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 18/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 19/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 20/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 21/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 22/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 23/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 24/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: nan - val_loss: nan
# Epoch 25/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: nan - val_loss: nan
# Epoch 26/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: nan - val_loss: nan
# Epoch 27/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: nan - val_loss: nan
# Epoch 28/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 29/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 30/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 31/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 32/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 33/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 34/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 35/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 36/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 37/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 38/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: nan - val_loss: nan
# Epoch 39/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: nan - val_loss: nan
# Epoch 40/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: nan - val_loss: nan
# Epoch 41/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: nan - val_loss: nan
# Epoch 42/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 43/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 44/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 45/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 46/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 47/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 48/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 49/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 50/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 51/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 52/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 53/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan - val_loss: nan
# Epoch 54/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: nan - val_loss: nan
# Epoch 55/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: nan - val_loss: nan
# Epoch 56/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 57/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 58/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 59/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 60/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 61/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: nan - val_loss: nan
# Epoch 62/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: nan - val_loss: nan
# Epoch 63/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: nan - val_loss: nan
# Epoch 64/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 65/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 66/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: nan - val_loss: nan
# Epoch 67/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: nan - val_loss: nan
# Epoch 68/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan - val_loss: nan
# Epoch 69/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: nan - val_loss: nan
# Epoch 70/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 71/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 72/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 73/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 74/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 75/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 76/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 77/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 78/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 79/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 80/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan - val_loss: nan
# Epoch 81/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: nan - val_loss: nan
# Epoch 82/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: nan - val_loss: nan
# Epoch 83/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 84/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 85/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 86/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: nan - val_loss: nan
# Epoch 87/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 88/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 89/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: nan - val_loss: nan
# Epoch 90/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 91/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 92/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: nan - val_loss: nan
# Epoch 93/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: nan - val_loss: nan
# Epoch 94/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: nan - val_loss: nan
# Epoch 95/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: nan - val_loss: nan
# Epoch 96/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 97/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 98/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 99/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 100/100
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
